# %% [markdown]
# # SYSU-MM01 Training

# %%
# %run train.py --dataset sysu --method fl --lr 0.2
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='sysu', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='fl', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset sysu statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   194 |     4721 |      1
#   -----------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset sysu statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   195 |     5753 |      2
#   -----------------------------------------
# ==> Building client2 model..
# ...

# %% [markdown]
# # SYSU-MM01 Testing

# %%
# %run test.py --dataset sysu --resume fl_sysu_p8_n8_lr0.2_sgd_seed_0.pth
# Out:
# ==> Building model......
# ==> Testing......
# ==> Loading weights from checkpoint......
# ==> best epoch 49
# Test Trial: 0
# original feature:   Rank-1: 46.07% | Rank-5: 76.52% | Rank-10: 85.88%| Rank-20: 93.58%| mAP: 44.16%| mINP: 28.36%
# feature after BN:   Rank-1: 52.54% | Rank-5: 79.78% | Rank-10: 88.98%| Rank-20: 95.48%| mAP: 50.41%| mINP: 35.22%
# Test Trial: 1
# original feature:   Rank-1: 43.20% | Rank-5: 75.39% | Rank-10: 86.46%| Rank-20: 94.82%| mAP: 42.15%| mINP: 27.01%
# feature after BN:   Rank-1: 49.75% | Rank-5: 80.54% | Rank-10: 89.17%| Rank-20: 95.58%| mAP: 49.21%| mINP: 34.63%
# Test Trial: 2
# original feature:   Rank-1: 45.91% | Rank-5: 75.83% | Rank-10: 86.98%| Rank-20: 94.95%| mAP: 42.88%| mINP: 26.75%
# feature after BN:   Rank-1: 51.14% | Rank-5: 81.17% | Rank-10: 89.40%| Rank-20: 95.40%| mAP: 49.54%| mINP: 34.49%
# Test Trial: 3
# original feature:   Rank-1: 44.02% | Rank-5: 75.52% | Rank-10: 85.67%| Rank-20: 94.16%| mAP: 42.16%| mINP: 26.77%
# ...

# %% [markdown]
# # RegDB Training (Split ten times and take the average)

# %%
# %run train.py --dataset regdb --trial 1
# %run train.py --dataset regdb --trial 2
# %run train.py --dataset regdb --trial 3
# %run train.py --dataset regdb --trial 4
# %run train.py --dataset regdb --trial 5
# %run train.py --dataset regdb --trial 6
# %run train.py --dataset regdb --trial 7
# %run train.py --dataset regdb --trial 8
# %run train.py --dataset regdb --trial 9
# %run train.py --dataset regdb --trial 10
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='regdb', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='fl', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset regdb statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   206 |     2060 |      1
#   -----------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset regdb statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   206 |     2060 |      2
#   -----------------------------------------
# ==> Building client2 model..
# ...

# %% [markdown]
# # RegDB Testing

# %%
# %run test.py --dataset regdb
# Out:
# ==> Building model......
# ==> Testing......
# ==> best epoch 49
# Test Trial: 1, Thermal to Visible
# original feature:   Rank-1: 52.14% | Rank-5: 67.33% | Rank-10: 74.76%| Rank-20: 82.18%| mAP: 47.31%| mINP: 32.18%
# feature after BN:   Rank-1: 59.17% | Rank-5: 69.51% | Rank-10: 76.21%| Rank-20: 82.96%| mAP: 54.96%| mINP: 42.40%
# ==> best epoch 49
# Test Trial: 2, Thermal to Visible
# original feature:   Rank-1: 46.99% | Rank-5: 61.46% | Rank-10: 69.71%| Rank-20: 79.03%| mAP: 40.21%| mINP: 24.89%
# feature after BN:   Rank-1: 56.99% | Rank-5: 69.32% | Rank-10: 76.07%| Rank-20: 84.13%| mAP: 53.25%| mINP: 40.13%
# ==> best epoch 49
# Test Trial: 3, Thermal to Visible
# original feature:   Rank-1: 51.02% | Rank-5: 68.40% | Rank-10: 75.19%| Rank-20: 81.26%| mAP: 41.87%| mINP: 22.34%
# feature after BN:   Rank-1: 62.91% | Rank-5: 73.01% | Rank-10: 80.78%| Rank-20: 86.65%| mAP: 58.13%| mINP: 43.86%
# ==> best epoch 49
# Test Trial: 4, Thermal to Visible
# ...

# %% [markdown]
# # LLCM Training

# %%
# %run train.py --dataset llcm --method fl --lr 0.2
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='llcm', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='fl', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset llcm statistics:
#   ------------------------------------------
#   subset   | # ids | # images | # client
#   ------------------------------------------
#   images  |    21 |      343 |      1
#   ------------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset llcm statistics:
#   ------------------------------------------
#   subset   | # ids | # images | # client
#   ------------------------------------------
#   images  |    20 |      137 |      2
#   ------------------------------------------
# ...

# %% [markdown]
# # LLCM Testing

# %%
# %run test.py --dataset llcm --resume fl_llcm_p8_n8_lr0.2_sgd_seed_0.pth
# Out:
# ==> Building model......
# ==> Testing......
# ==> Loading weights from checkpoint......
# ==> best epoch 49
# Test Trial: 0
# original feature:   Rank-1: 33.62% | Rank-5: 55.86% | Rank-10: 65.14%| Rank-20: 74.99%| mAP: 40.49%| mINP: 37.09%
# feature after BN:   Rank-1: 34.98% | Rank-5: 58.32% | Rank-10: 67.64%| Rank-20: 76.65%| mAP: 42.56%| mINP: 39.30%
# Test Trial: 1
# original feature:   Rank-1: 32.29% | Rank-5: 53.08% | Rank-10: 62.89%| Rank-20: 73.05%| mAP: 39.37%| mINP: 36.33%
# feature after BN:   Rank-1: 33.16% | Rank-5: 56.00% | Rank-10: 65.87%| Rank-20: 76.47%| mAP: 40.90%| mINP: 37.73%
# Test Trial: 2
# original feature:   Rank-1: 31.06% | Rank-5: 54.03% | Rank-10: 64.22%| Rank-20: 75.31%| mAP: 38.40%| mINP: 34.98%
# feature after BN:   Rank-1: 33.25% | Rank-5: 56.57% | Rank-10: 67.22%| Rank-20: 77.64%| mAP: 40.87%| mINP: 37.32%
# Test Trial: 3
# original feature:   Rank-1: 33.63% | Rank-5: 53.49% | Rank-10: 62.77%| Rank-20: 72.45%| mAP: 39.46%| mINP: 35.80%
# ...
