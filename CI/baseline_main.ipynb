# %% [markdown]
# # Training SYSU-MM01 (Baseline)

# %%
# %run train_baseline.py --dataset sysu --method baseline --lr 0.2
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='sysu', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='baseline', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset sysu statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   194 |     4721 |      1
#   -----------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset sysu statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   195 |     5753 |      2
#   -----------------------------------------
# ...

# %%
# %run test.py --dataset sysu --resume baseline_sysu_p8_n8_lr0.2_sgd_seed_0.pth
# Out:
# ==> Building model......
# ==> Testing......
# ==> Loading weights from checkpoint......
# ==> best epoch 49
# Test Trial: 0
# original feature:   Rank-1: 22.90% | Rank-5: 46.07% | Rank-10: 58.19%| Rank-20: 71.97%| mAP: 23.42%| mINP: 13.53%
# feature after BN:   Rank-1: 30.87% | Rank-5: 60.72% | Rank-10: 73.78%| Rank-20: 86.54%| mAP: 31.51%| mINP: 19.17%
# Test Trial: 1
# original feature:   Rank-1: 20.56% | Rank-5: 43.18% | Rank-10: 58.06%| Rank-20: 74.52%| mAP: 22.95%| mINP: 14.72%
# feature after BN:   Rank-1: 26.95% | Rank-5: 57.11% | Rank-10: 71.92%| Rank-20: 85.51%| mAP: 30.48%| mINP: 20.62%
# Test Trial: 2
# original feature:   Rank-1: 21.46% | Rank-5: 46.17% | Rank-10: 58.32%| Rank-20: 72.97%| mAP: 23.54%| mINP: 15.15%
# feature after BN:   Rank-1: 24.74% | Rank-5: 55.27% | Rank-10: 71.71%| Rank-20: 85.20%| mAP: 29.09%| mINP: 20.09%
# Test Trial: 3
# original feature:   Rank-1: 21.25% | Rank-5: 45.02% | Rank-10: 56.56%| Rank-20: 70.34%| mAP: 23.32%| mINP: 14.89%
# ...

# %% [markdown]
# # # RegDB Training (Baseline)

# %%
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 1
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 2
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 3
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 4
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 5
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 6
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 7
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 8
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 9
# %run train_baseline.py --dataset regdb --method baseline --lr 0.2 --trial 10
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='regdb', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='baseline', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset regdb statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   206 |     2060 |      1
#   -----------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset regdb statistics:
#   -----------------------------------------
#   subset   | # ids | # images | # client
#   -----------------------------------------
#   images  |   206 |     2060 |      2
#   -----------------------------------------
# ...

# %% [markdown]
# # RegDB Testing (Baseline)

# %%
# %run test.py --dataset regdb --method baseline
# Out:
# ==> Building model......
# ==> Testing......
# ==> best epoch 49
# Test Trial: 1, Thermal to Visible
# original feature:   Rank-1: 9.95% | Rank-5: 17.43% | Rank-10: 22.52%| Rank-20: 31.02%| mAP: 8.62%| mINP: 3.61%
# feature after BN:   Rank-1: 19.85% | Rank-5: 28.54% | Rank-10: 35.24%| Rank-20: 45.97%| mAP: 22.81%| mINP: 17.27%
# ==> best epoch 49
# Test Trial: 2, Thermal to Visible
# original feature:   Rank-1: 17.57% | Rank-5: 25.34% | Rank-10: 30.53%| Rank-20: 37.82%| mAP: 13.92%| mINP: 6.32%
# feature after BN:   Rank-1: 21.94% | Rank-5: 31.75% | Rank-10: 37.28%| Rank-20: 46.36%| mAP: 21.73%| mINP: 15.05%
# ==> best epoch 49
# Test Trial: 3, Thermal to Visible
# original feature:   Rank-1: 18.74% | Rank-5: 30.44% | Rank-10: 36.99%| Rank-20: 45.15%| mAP: 15.99%| mINP: 5.72%
# feature after BN:   Rank-1: 27.23% | Rank-5: 38.98% | Rank-10: 47.96%| Rank-20: 60.87%| mAP: 29.30%| mINP: 20.89%
# ==> best epoch 49
# Test Trial: 4, Thermal to Visible
# ...

# %% [markdown]
# # LLCM Training (Baseline)

# %%
# %run train_baseline.py --dataset llcm --method baseline --lr 0.2
# Out:
# ...
# Args:Namespace(FL=True, batch_size=8, dataset='llcm', decay_step=16, dim=2048, gpu='0,1,2,3', img_h=288, img_w=144, log_path='log/', lr=0.2, lr_multipliers=[0.1, 1.0, 1.0], margin=0.5, max_epoch=50, method='baseline', mode='all', model_path='save_model/', num_pos=8, optim='sgd', pool_dim=2048, rerank='no', save_epoch=1000, seed=0, test_batch=64, trial=1, tta=False, warm_up_epoch=8, workers=4)
# ...
# ==> Loading data..
# Dataset llcm statistics:
#   ------------------------------------------
#   subset   | # ids | # images | # client
#   ------------------------------------------
#   images  |    21 |      343 |      1
#   ------------------------------------------
# ==> Building client1 model..
# ==> Building success!..
# Dataset llcm statistics:
#   ------------------------------------------
#   subset   | # ids | # images | # client
#   ------------------------------------------
#   images  |    20 |      137 |      2
#   ------------------------------------------
# ...

# %% [markdown]
# # LLCM Testing (Baseline)

# %%
# %run test.py --dataset llcm --resume baseline_llcm_p8_n8_lr0.2_sgd_seed_0.pth
# Out:
# ==> Building model......
# ==> Testing......
# ==> Loading weights from checkpoint......
# ==> best epoch 49
# Test Trial: 0
# original feature:   Rank-1: 21.84% | Rank-5: 39.65% | Rank-10: 49.25%| Rank-20: 60.73%| mAP: 27.85%| mINP: 24.87%
# feature after BN:   Rank-1: 26.12% | Rank-5: 48.65% | Rank-10: 58.68%| Rank-20: 69.73%| mAP: 33.31%| mINP: 30.07%
# Test Trial: 1
# original feature:   Rank-1: 21.80% | Rank-5: 40.58% | Rank-10: 50.17%| Rank-20: 61.74%| mAP: 28.63%| mINP: 26.03%
# feature after BN:   Rank-1: 24.84% | Rank-5: 47.33% | Rank-10: 58.04%| Rank-20: 70.30%| mAP: 32.98%| mINP: 30.01%
# Test Trial: 2
# original feature:   Rank-1: 21.46% | Rank-5: 39.42% | Rank-10: 49.51%| Rank-20: 61.72%| mAP: 27.60%| mINP: 24.36%
# feature after BN:   Rank-1: 25.31% | Rank-5: 46.68% | Rank-10: 59.31%| Rank-20: 70.95%| mAP: 32.41%| mINP: 28.93%
# Test Trial: 3
# original feature:   Rank-1: 22.38% | Rank-5: 40.86% | Rank-10: 49.65%| Rank-20: 60.40%| mAP: 28.20%| mINP: 24.90%
# ...
