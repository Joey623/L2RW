# %% [markdown]
# # DEEN

# %%
# R_S_to_L
# source domain: Regdb, SYSU
# unseen domain: LLCM
# %run train.py --protocol R_S_to_L
# Out:
# trainset: RegDB, SYSU
# testset: LLCM
# ...
# Args:Namespace(arch='resnet50', batch_size=6, erasing_p=0.5, gpu='0,1,2,3', img_h=384, img_w=144, lambda_1=0.8, lambda_2=0.01, log_path='log/', lr=0.1, margin=0.3, max_epoch=30, method='deen', mode='all', model_path='save_model/', num_pos=4, optim='sgd', protocol='R_S_to_L', resume='', save_epoch=20, seed=0, test_batch=4, test_only=False, trial=1, vis_log_path='log/vis_log/', workers=4)
# ...
# ==> Loading data..
# ==> Testing dataset: LLCM
# data init success!
# Protocol R_S_to_L statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   visible  |   601 |    24318
#   thermal  |   601 |    13969
#   ------------------------------
#   query    |   351 |     7166
#   gallery  |   351 |      484
#   ------------------------------
# Data Loading Time:	 21.862
# ==> Start Training...
# ==> Preparing Data Loader...
# ...

# %%
# R_L_to_S
# source domain: Regdb, LLCM
# unseen domain: SYSU
# %run train.py --protocol R_L_to_S
# Out:
# trainset: RegDB, LLCM
# testset: SYSU
# ...
# Args:Namespace(arch='resnet50', batch_size=6, erasing_p=0.5, gpu='0,1,2,3', img_h=384, img_w=144, lambda_1=0.8, lambda_2=0.01, log_path='log/', lr=0.1, margin=0.3, max_epoch=30, method='deen', mode='all', model_path='save_model/', num_pos=4, optim='sgd', protocol='R_L_to_S', resume='', save_epoch=20, seed=0, test_batch=4, test_only=False, trial=1, vis_log_path='log/vis_log/', workers=4)
# ...
# ==> Loading data..
# ==> Testing dataset: SYSU-MM01
# data init success!
# Protocol R_L_to_S statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   visible  |   919 |    19006
#   thermal  |   919 |    16035
#   ------------------------------
#   query    |    96 |     3803
#   gallery  |    96 |      301
#   ------------------------------
# Data Loading Time:	 20.841
# ==> Start Training...
# ==> Preparing Data Loader...
# ...

# %%
# L_S_to_R
# source domain: LLCM, SYSU
# unseen domain: RegDB
# %run train.py --protocol L_S_to_R
import os
os.system("shutdown")
# Out:
# trainset: LLCM, SYSU
# testset: RegDB
# ...
# Args:Namespace(arch='resnet50', batch_size=6, erasing_p=0.5, gpu='0,1,2,3', img_h=384, img_w=144, lambda_1=0.8, lambda_2=0.01, log_path='log/', lr=0.1, margin=0.3, max_epoch=30, method='deen', mode='all', model_path='save_model/', num_pos=4, optim='sgd', protocol='L_S_to_R', resume='', save_epoch=20, seed=0, test_batch=4, test_only=False, trial=1, vis_log_path='log/vis_log/', workers=4)
# ...
# ==> Loading data..
# ==> Testing dataset: RegDB
# data init success!
# Protocol L_S_to_R statistics:
#   ------------------------------
#   subset   | # ids | # images
#   ------------------------------
#   visible  |  1108 |    39204
#   thermal  |  1108 |    25884
#   ------------------------------
#   query    |   206 |     2060
#   gallery  |   206 |     2060
#   ------------------------------
# Data Loading Time:	 29.285
# ==> Start Training...
# ==> Preparing Data Loader...
# ...
