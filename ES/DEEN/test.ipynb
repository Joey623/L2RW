# %% [markdown]
# ## R+S->L

# %%
# %run test.py --protocol R_S_to_L --resume R_S_to_L_deen_p6_n4_lr_0.1_seed_0_best.t
# Out:
# ==> Building model..
# ==> Loading data..
# Protocol:R_S_to_L
# ==> Loading weights from checkpoint......
# ==> best epoch 17
# Extracting Query Feature...
# Extracting Time:	 19.541
# Extracting Gallery Feature...
# Extracting Time:	 1.912
# LLCM Test Trial: 0
# original feature:   Rank-1: 10.61% | Rank-5: 21.39% | Rank-10: 28.72%| Rank-20: 38.96%| mAP: 13.79%| mINP: 11.21%
# feature after BN:   Rank-1: 10.54% | Rank-5: 21.52% | Rank-10: 28.62%| Rank-20: 39.25%| mAP: 13.92%| mINP: 11.40%
# Extracting Gallery Feature...
# Extracting Time:	 1.586
# LLCM Test Trial: 1
# original feature:   Rank-1: 10.86% | Rank-5: 22.54% | Rank-10: 29.61%| Rank-20: 40.64%| mAP: 14.41%| mINP: 11.65%
# feature after BN:   Rank-1: 10.88% | Rank-5: 22.15% | Rank-10: 29.68%| Rank-20: 40.27%| mAP: 14.41%| mINP: 11.65%
# Extracting Gallery Feature...
# Extracting Time:	 1.590
# LLCM Test Trial: 2
# ...

# %% [markdown]
# ## R+L->S

# %%
# %run test.py --protocol R_L_to_S --resume R_L_to_S_deen_p6_n4_lr_0.1_seed_0_best.t
# Out:
# ==> Building model..
# ==> Loading data..
# Protocol:R_L_to_S
# ==> Loading weights from checkpoint......
# ==> best epoch 29
# Extracting Query Feature...
# Extracting Time:	 11.276
# Extracting Gallery Feature...
# Extracting Time:	 1.530
# SYSU Test Trial: 0
# original feature:   Rank-1: 10.04% | Rank-5: 26.48% | Rank-10: 39.50%| Rank-20: 56.03%| mAP: 10.47%| mINP: 3.97%
# feature after BN:   Rank-1: 10.18% | Rank-5: 26.79% | Rank-10: 39.57%| Rank-20: 55.59%| mAP: 10.45%| mINP: 3.89%
# Extracting Gallery Feature...
# Extracting Time:	 1.090
# SYSU Test Trial: 1
# original feature:   Rank-1: 9.86% | Rank-5: 26.66% | Rank-10: 39.21%| Rank-20: 55.98%| mAP: 10.54%| mINP: 4.02%
# feature after BN:   Rank-1: 10.07% | Rank-5: 27.56% | Rank-10: 39.39%| Rank-20: 55.46%| mAP: 10.57%| mINP: 3.89%
# Extracting Gallery Feature...
# Extracting Time:	 1.127
# SYSU Test Trial: 2
# original feature:   Rank-1: 8.99% | Rank-5: 25.19% | Rank-10: 38.10%| Rank-20: 54.90%| mAP: 9.97%| mINP: 4.24%
# ...

# %% [markdown]
# ## L+S->R

# %%
# %run test.py --protocol L_S_to_R --resume L_S_to_R_deen_p6_n4_lr_0.1_seed_0_best.t
# Out:
# ==> Building model..
# ==> Loading data..
# Protocol:L_S_to_R
# ==> Loading weights from checkpoint......
# ==> best epoch 18
# Data Loading Time:	 7.553
# Extracting Query Feature...
# Extracting Time:	 6.697
# Extracting Gallery Feature...
# Extracting Time:	 5.508
# RegDB Test Trial: 1
# original feature:   Rank-1: 20.24% | Rank-5: 29.08% | Rank-10: 35.15%| Rank-20: 44.22%| mAP: 19.46%| mINP: 12.23%
# feature after BN:   Rank-1: 23.16% | Rank-5: 34.32% | Rank-10: 40.10%| Rank-20: 48.25%| mAP: 22.15%| mINP: 13.50%
# Data Loading Time:	 40.538
# Extracting Query Feature...
# Extracting Time:	 5.691
# Extracting Gallery Feature...
# Extracting Time:	 5.554
# RegDB Test Trial: 2
# original feature:   Rank-1: 18.64% | Rank-5: 28.79% | Rank-10: 35.44%| Rank-20: 43.40%| mAP: 17.68%| mINP: 10.78%
# feature after BN:   Rank-1: 20.49% | Rank-5: 30.92% | Rank-10: 38.35%| Rank-20: 44.95%| mAP: 19.42%| mINP: 12.25%
# Data Loading Time:	 72.381
# Extracting Query Feature...
# ...
